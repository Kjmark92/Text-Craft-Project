# %%
# Cirque du Soleil Reviews

# %%
#URLs per show (those in Vegas)

#Zumanity
#yelp_rest_url = "https://www.yelp.com/biz/cirque-du-soleil-zumanity-las-vegas-2"

#Mystere
#yelp_rest_url = "https://www.yelp.com/biz/cirque-du-soleil-myst%C3%A8re-las-vegas-2"

#KA - did not work.
#yelp_rest_url = "https://www.yelp.com/biz/ka-by-cirque-du-soleil-las-vegas-3"

#O
#yelp_rest_url = "https://www.yelp.com/biz/cirque-du-soleil-o-las-vegas-2"

#MJ One
#yelp_rest_url = "https://www.yelp.com/biz/cirque-du-soleil-michael-jackson-one-las-vegas"

#Beatles Love
yelp_rest_url = "https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas"

# %%
import urllib
import time 
import random

# %%
user_agents = [
    'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36',
    'Opera/9.80 (X11; Linux i686; Ubuntu/14.10) Presto/2.12.388 Version/12.16',
    'Mozilla/5.0 (Windows; U; Windows NT 6.1; rv:2.2) Gecko/20110201',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.75.14 (KHTML, like Gecko) Version/7.0.3 Safari/7046A194A',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
    ]




rest_name = 'Cirque du Soleil - Beatles Love'

#dynamic entry of restaurant names
#yelp_rest_url = yelp_restaurant_url[0:yelp_restaurant_url.find('biz/')+4]+rest_name
#yelp_rest_url

str1 = '{"aggregateRating": {"reviewCount":'
rcstr =''
html = urllib.request.urlopen(yelp_rest_url).read().decode('utf-8') 

#finding the number of reviews

index = html.find(str1)
rcstr = html[index:]
rcstr = rcstr[len(str1)+1:rcstr.find(',')]
review_count = int(rcstr)
review_count
# Out:
# 2130

# %%
rev_name =[]
rev_desc =[]
rest_namel=[]
str2 = '<meta itemprop="author" content="'
str3 = '<p itemprop="description">'

#looping through each page and getting the list of reviews to append to empty lists

for i in range(0,review_count,20):
    yelp_rest_url1 = ''
    yelp_rest_url1 = yelp_rest_url+'?start='+str(i)
    print(yelp_rest_url1)
    
    #html = urllib.request.urlopen(yelp_rest_url1).read().decode('utf-8') 
    
    
    urlreq = urllib.request.Request(url=yelp_rest_url1, headers = {'User-Agent':random.choice(user_agents)})
    time.sleep(random.uniform(5,10))
    f = urllib.request.urlopen(urlreq)
    html = f.read().decode('utf-8')
    
    
    
    
    #time.sleep(5) 
    #To check if page is getting loaded, if not load again
    if html.find(str1) == '':
        time.sleep(2)
        html = urllib.request.urlopen(yelp_rest_url).read().decode('utf-8')
    
    #getting author names
    start = html.find(str2)
    auth = html[start:]
    while auth.find(str2) != -1:
        start = auth.find(str2)
        rem = auth[start:]
        end = rem.find('.')
        rev_name.append(rem[len(str2):end])
        rem=rem[end:]
        auth=rem[end:]
        
    #getting review names
    start1 = html.find(str3)
    auth1 = html[start1:]
    while auth1.find(str3) != -1:
        start1 = auth1.find(str3)
        rem1 = auth1[start1:]
        end1 = rem1.find('<p>')
        rev_desc.append(rem1[len(str3):end1])
        rem1=rem1[end1:]
        auth1=rem1[end1:]
        
#duplicating restaurant names
for i in range(0,len(rev_name)):
        rest_namel.append(rest_name)

#getting the output csv
import csv
print(len(rest_namel))

csvData = zip(rest_namel,rev_name,rev_desc)

with open('Cirque-Beatles Love.csv', 'w') as f:
        writerf = csv.writer(f)
        writerf.writerows(csvData)
# Out:
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=0
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=20
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=40
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=60
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=80
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=100
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=120
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=140
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=160
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=180
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=200
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=220
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=240
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=260
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=280
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=300
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=320
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=340
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=360
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=380
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=400
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=420
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=440
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=460
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=480
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=500
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=520
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=540
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=560
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=580
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=600
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=620
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=640
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=660
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=680
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=700
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=720
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=740
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=760
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=780
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=800
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=820
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=840
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=860
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=880
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=900
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=920
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=940
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=960
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=980
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1000
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1020
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1040
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1060
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1080
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1100
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1120
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1140
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1160
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1180
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1200
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1220
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1240
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1260
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1280
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1300
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1320
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1340
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1360
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1380
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1400
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1420
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1440
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1460
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1480
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1500
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1520
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1540
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1560
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1580
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1600
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1620
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1640
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1660
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1680
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1700
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1720
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1740
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1760
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1780
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1800
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1820
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1840
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1860
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1880
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1900
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1920
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1940
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1960
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=1980
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=2000
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=2020
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=2040
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=2060
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=2080
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=2100
# https://www.yelp.com/biz/cirque-du-soleil-the-beatles-love-las-vegas?start=2120
# 2127
